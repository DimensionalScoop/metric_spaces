# %%
"""Try to find a solution for ρ' > ρ,
when going from (M, d) |-> (M, sqrt(d)).
This seems to be impossible for the general case,
and assuming D ~ N(μ,σ) is a bad idea:
What happens to sqrt(D) for negative distances?
"""
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
from sympy.stats import P, E, variance, Normal, Variance, Expectation
import sympy.stats as stats

# %%
X = stats.symbolic_probability.RandomSymbol("X")

# intrinsic dim for a metric space (M,d),
# where X = d(a,b) with a,b \in M and randomly chosen
rho = Expectation(X) ** 2 / (2 * Variance(X))
simplify(rho)
# Out:
# Expectation(X)**2*Variance(X)**(-1)/2

# %%
rho_quad = rho.subs(X, X**2)
# if the original space becomes more complicated
# by mapping d -> \sqrt(d), we call it "worse":
original = rho_quad
sqrt_space = rho
is_worse = original < sqrt_space
simplify(is_worse)
# Out:
# Expectation(X)**2*Variance(X)**(-1)/2 > Expectation(X**2)**2*Variance(X**2)**(-1)/2

# %%
mu, sig = symbols("\mu \sigma", positive=True)
Z = Normal("Z", mu, sig)
worse_N = is_worse.subs({X: sqrt(abs(Z))})
simplify(worse_N)
# Out:
# ---------------------------------------------------------------------------
# PolynomialError                           Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6542, in factor(f, deep, *gens, **args)
#    6541 try:
# -> 6542     return _generic_factor(f, gens, args, method='factor')
#    6543 except PolynomialError as msg:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6223, in _generic_factor(expr, gens, args, method)
#    6222 opt['fraction'] = fraction
# -> 6223 return _symbolic_factor(sympify(expr), opt, method)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6163, in _symbolic_factor(expr, opt, method)
#    6162     return expr._eval_factor()
# -> 6163 coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6164 return _keep_coeff(coeff, _factors_product(factors))
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6122, in _symbolic_factor_list(expr, opt, method)
#    6121 try:
# -> 6122     poly, _ = _poly_from_expr(base, opt)
#    6123 except PolificationFailed as exc:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:4479, in _poly_from_expr(expr, opt)
#    4477     expr = expr.expand()
# -> 4479 rep, opt = _dict_from_expr(expr, opt)
#    4480 if not opt.gens:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:348, in _dict_from_expr(expr, opt)
#     347 if expr.is_commutative is False:
# --> 348     raise PolynomialError('non-commutative expressions are not supported')
#     350 def _is_expandable_pow(expr):
#
# PolynomialError: non-commutative expressions are not supported
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 Z = Normal("Z", mu, sig)
#       3 worse_N = is_worse.subs({X:sqrt(abs(Z))})
# ----> 4 simplify(worse_N)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/simplify/simplify.py:601, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     599 _eval_simplify = getattr(expr, '_eval_simplify', None)
#     600 if _eval_simplify is not None:
# --> 601     return _eval_simplify(**kwargs)
#     603 original_expr = expr = collect_abs(signsimp(expr))
#     605 if not isinstance(expr, Basic) or not expr.args:  # XXX: temporary hack
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/relational.py:428, in Relational._eval_simplify(self, **kwargs)
#     426 if dif.is_comparable:
#     427     v = dif.n(2)
# --> 428 elif dif.equals(0):  # XXX this is expensive
#     429     v = S.Zero
#     430 if v is not None:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/expr.py:741, in Expr.equals(self, other, failing_expression)
#     735     return True
#     737 # they aren't the same so see if we can make the difference 0;
#     738 # don't worry about doing simplification steps one at a time
#     739 # because if the expression ever goes to 0 then the subsequent
#     740 # simplification steps that are done will be very fast.
# --> 741 diff = factor_terms(simplify(self - other), radical=True)
#     743 if not diff:
#     744     return True
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/simplify/simplify.py:696, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     693     expr = kroneckersimp(expr)
#     695 if expr.has(BesselBase):
# --> 696     expr = besselsimp(expr)
#     698 if expr.has(TrigonometricFunction, HyperbolicFunction):
#     699     expr = trigsimp(expr, deep=True)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/simplify/simplify.py:1316, in besselsimp(expr)
#    1314 expr = _bessel_simp_recursion(expr)
#    1315 if expr != orig_expr:
# -> 1316     expr = expr.factor()
#    1318 return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/expr.py:3786, in Expr.factor(self, *gens, **args)
#    3784 """See the factor() function in sympy.polys.polytools"""
#    3785 from sympy.polys.polytools import factor
# -> 3786 return factor(self, *gens, **args)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6545, in factor(f, deep, *gens, **args)
#    6543 except PolynomialError as msg:
#    6544     if not f.is_commutative:
# -> 6545         return factor_nc(f)
#    6546     else:
#    6547         raise PolynomialError(msg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/exprtools.py:1414, in factor_nc(expr)
#    1412     return expr
#    1413 if not expr.is_Add:
# -> 1414     return expr.func(*[factor_nc(a) for a in expr.args])
#    1415 expr = expr.func(*[expand_power_exp(i) for i in expr.args])
#    1417 from sympy.polys.polytools import gcd, factor
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/exprtools.py:1414, in <listcomp>(.0)
#    1412     return expr
#    1413 if not expr.is_Add:
# -> 1414     return expr.func(*[factor_nc(a) for a in expr.args])
#    1415 expr = expr.func(*[expand_power_exp(i) for i in expr.args])
#    1417 from sympy.polys.polytools import gcd, factor
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/exprtools.py:1418, in factor_nc(expr)
#    1415 expr = expr.func(*[expand_power_exp(i) for i in expr.args])
#    1417 from sympy.polys.polytools import gcd, factor
# -> 1418 expr, rep, nc_symbols = _mask_nc(expr)
#    1420 if rep:
#    1421     return factor(expr).subs(rep)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/exprtools.py:1387, in _mask_nc(eq, name)
#    1385     rep.append((n, nc))
#    1386     nc_syms.add(nc)
# -> 1387 expr = expr.subs(rep)
#    1389 nc_syms = list(nc_syms)
#    1390 nc_syms.sort(key=default_sort_key)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1040, in Basic.subs(self, *args, **kwargs)
#    1038 rv = self
#    1039 for old, new in sequence:
# -> 1040     rv = rv._subs(old, new, **kwargs)
#    1041     if not isinstance(rv, Basic):
#    1042         break
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
#     [... skipping similar frames: Basic._subs at line 1154 (5 times), __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (5 times), Basic._subs.<locals>.fallback at line 1126 (4 times)]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/basic.py:1131, in Basic._subs.<locals>.fallback(self, old, new)
#    1129         args[i] = arg
#    1130 if hit:
# -> 1131     rv = self.func(*args)
#    1132     hack2 = hints.get('hack2', False)
#    1133     if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/functions/special/hyper.py:195, in hyper.__new__(cls, ap, bq, z, **kwargs)
#     193 def __new__(cls, ap, bq, z, **kwargs):
#     194     # TODO should we check convergence conditions?
# --> 195     return Function.__new__(cls, _prep_tuple(ap), _prep_tuple(bq), z, **kwargs)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/functions/special/hyper.py:54, in _prep_tuple(v)
#      37 def _prep_tuple(v):
#      38     """
#      39     Turn an iterable argument *v* into a tuple and unpolarify, since both
#      40     hypergeometric and meijer g-functions are unbranched in their parameters.
#    (...)
#      52
#      53     """
# ---> 54     return TupleArg(*[unpolarify(x) for x in v])
#
# TypeError: 'Dummy' object is not iterable

# %%
from scipy.stats import norm as n_normal

plt.hist(np.abs(n_normal(20, 20).rvs(100000)), bins=100);

# %%
# we know that (M, \sqrt(d)) should be Ptolemaic
# but writing X**2 is easier than \sqrt(X)
rho_quad = E(X**2) ** 2 / (2 * variance(X**2))
rho_sqr = E(sqrt(X)) ** 2 / (2 * variance(sqrt(X)))
simplify(rho_sqr)
# Out:
# Expectation(sqrt(X))**2*Variance(sqrt(X))**(-1)/2

# %%
# is the intrinsic dim always higher when mapping
# d -> \sqrt(d) ?
is_more_complex = rho < rho_sqr
is_more_complex
# Out:
# Expectation(X)**2*Variance(X)**(-1)/2 < Expectation(sqrt(X))**2*Variance(sqrt(X))**(-1)/2

# %%
# sympy fails at simplifying the sqrt expression
# let's assume our original distribution uses X**2
# and the Pto. version X

original = rho_quad
projected_space = rho
is_more_complex = original < projected_space
is_more_complex
# Out:
# Expectation(X**2)**2*Variance(X**2)**(-1)/2 < Expectation(X)**2*Variance(X)**(-1)/2

# %%
# for reasons I don't understand yet, the simplifier does
# not replace these:
delta = delta.subs({Variance(Z) ** (-1): sig ** (-2), Variance(Z**2): variance(Z**2)})
delta = simplify(delta)
delta_n = lambdify((mu, sig), delta, "numpy")
delta
# Out:
# \mu**2/(2*\sigma**2) < Expectation(X)**2*Variance(X)**(-1)/2

# %%
solve(delta, sig)
# Out:
# ---------------------------------------------------------------------------
# PolynomialError                           Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:809, in _solve_inequality(ie, s, linear)
#     808 try:
# --> 809     p = Poly(expr, s)
#     810     if p.degree() == 0:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:311, in Poly._from_expr(cls, rep, opt)
#     310 """Construct a polynomial from an expression. """
# --> 311 rep, opt = _dict_from_expr(rep, opt)
#     312 return cls._from_dict(rep, opt)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:348, in _dict_from_expr(expr, opt)
#     347 if expr.is_commutative is False:
# --> 348     raise PolynomialError('non-commutative expressions are not supported')
#     350 def _is_expandable_pow(expr):
#
# PolynomialError: non-commutative expressions are not supported
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:247, in reduce_rational_inequalities(exprs, gen, relational)
#     246 try:
# --> 247     (numer, denom), opt = parallel_poly_from_expr(
#     248         (numer, denom), gen)
#     249 except PolynomialError:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:4504, in parallel_poly_from_expr(exprs, *gens, **args)
#    4503 opt = options.build_options(gens, args)
# -> 4504 return _parallel_poly_from_expr(exprs, opt)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:4555, in _parallel_poly_from_expr(exprs, opt)
#    4553         exprs[i] = exprs[i].as_expr()
# -> 4555 reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4556 if not opt.gens:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:329, in _parallel_dict_from_expr(exprs, opt)
#     328 if any(expr.is_commutative is False for expr in exprs):
# --> 329     raise PolynomialError('non-commutative expressions are not supported')
#     331 if opt.gens:
#
# PolynomialError: non-commutative expressions are not supported
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:818, in _solve_inequality(ie, s, linear)
#     817 try:
# --> 818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:250, in reduce_rational_inequalities(exprs, gen, relational)
#     249 except PolynomialError:
# --> 250     raise PolynomialError(filldedent('''
#     251         only polynomials and rational functions are
#     252         supported in this context.
#     253         '''))
#     255 if not opt.domain.is_Exact:
#
# PolynomialError:
# only polynomials and rational functions are supported in this context.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:521, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     519     if solns is None:
#     520         # in which case we raise ValueError
# --> 521         raise ValueError
#     522 except (ValueError, NotImplementedError):
#     523     # replace gen with generic x since it's
#     524     # univariate anyway
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 solve(delta, sig)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solvers.py:960, in solve(f, *symbols, **flags)
#     956     if warn and symbols[0].assumptions0:
#     957         warnings.warn(filldedent("""
#     958             \tWarning: assumptions about variable '%s' are
#     959             not handled currently.""" % symbols[0]))
# --> 960     return reduce_inequalities(f, symbols=symbols)
#     962 # convert Poly to expression
#     963 if isinstance(fi, Poly):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:981, in reduce_inequalities(inequalities, symbols)
#     978 del keep
#     980 # solve system
# --> 981 rv = _reduce_inequalities(inequalities, symbols)
#     983 # restore original symbols and return
#     984 return rv.xreplace({v: k for k, v in recast.items()})
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:903, in _reduce_inequalities(inequalities, symbols)
#     901 if len(common) == 1:
#     902     gen = common.pop()
# --> 903     other.append(_solve_inequality(Relational(expr, 0, rel), gen))
#     904     continue
#     905 else:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:820, in _solve_inequality(ie, s, linear)
#     818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
# --> 820     rv = solve_univariate_inequality(ie, s)
#     821 # remove restrictions wrt +/-oo that may have been
#     822 # applied when using sets to simplify the relationship
#     823 okoo = classify(ie, s, oo)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/inequalities.py:525, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     521         raise ValueError
#     522 except (ValueError, NotImplementedError):
#     523     # replace gen with generic x since it's
#     524     # univariate anyway
# --> 525     raise NotImplementedError(filldedent('''
#     526         The inequality, %s, cannot be solved using
#     527         solve_univariate_inequality.
#     528         ''' % expr.subs(gen, Symbol('x'))))
#     530 expanded_e = expand_mul(e)
#     531 def valid(x):
#     532     # this is used to see if gen=x satisfies the
#     533     # relational by substituting it into the
#    (...)
#     539     #
#     540     # expanded_e, expr and gen used from enclosing scope
#
# NotImplementedError:
# The inequality, -_X**2*Variance(_X)**(-1)/2 + \mu**2/(2*x**2) < 0,
# cannot be solved using solve_univariate_inequality.

# %%
# Out:
# Set(True)

# %%
# Out:
# Union(Intersection(Interval.open(0, 3**(1/4)*\mu), Set(True)), Intersection(Interval.open(-3**(1/4)*\mu, 0), Set(True)))

# %%
# Out:
# \sigma < 3**(1/4)*\mu

# %%
term = delta.args[1].args[0].args[1]
print(term)
# Out:
# Variance(Z)**(-1)

# %%
# Out:
# Reals

# %%
for term in delta.term:
    print(term)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 for term in delta:
#       2     print(term)
#
# TypeError: 'Mul' object is not iterable

# %%
variance(Z) ** (-1)
# Out:
# \sigma**(-2)

# %%
variance(Z**2)
# Out:
# 2*\mu**4 + 8*\mu**2*\sigma**2 + 4*\sigma**4 + 2*(-2*\mu**2 - 2*\sigma**2)*(\mu**2/2 + \sigma**2/2)

# %%
variance(sqrt(Z))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: sqrt(Z)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/crv.py:261, in SingleContinuousDistribution.expectation(self, expr, var, evaluate, **kwargs)
#     260 try:
# --> 261     p = poly(expr, var)
#     262     if p.is_zero:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:7388, in poly(expr, *gens, **args)
#    7386 opt = options.build_options(gens, args)
# -> 7388 return _poly(expr, opt)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:7338, in poly.<locals>._poly(expr, opt)
#    7335 elif factor.is_Pow and factor.base.is_Add and \
#    7336         factor.exp.is_Integer and factor.exp >= 0:
#    7337     poly_factors.append(
# -> 7338         _poly(factor.base, opt).pow(factor.exp))
#    7339 else:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:7361, in poly.<locals>._poly(expr, opt)
#    7360 if not poly_terms:
# -> 7361     result = Poly._from_expr(expr, opt)
#    7362 else:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:311, in Poly._from_expr(cls, rep, opt)
#     310 """Construct a polynomial from an expression. """
# --> 311 rep, opt = _dict_from_expr(rep, opt)
#     312 return cls._from_dict(rep, opt)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:368, in _dict_from_expr(expr, opt)
#     367 if opt.gens:
# --> 368     rep, gens = _dict_from_expr_if_gens(expr, opt)
#     369 else:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:307, in _dict_from_expr_if_gens(expr, opt)
#     306 """Transform an expression into a multinomial form given generators. """
# --> 307 (poly,), gens = _parallel_dict_from_expr_if_gens((expr,), opt)
#     308 return poly, gens
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: sqrt(Z) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 variance(sqrt(Z))
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/rv_interface.py:80, in variance(X, condition, **kwargs)
#      77     from sympy.stats.symbolic_probability import Variance
#      78     return Variance(X, condition)
# ---> 80 return cmoment(X, 2, condition, **kwargs)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/rv_interface.py:242, in cmoment(X, n, condition, evaluate, **kwargs)
#     240 from sympy.stats.symbolic_probability import CentralMoment
#     241 if evaluate:
# --> 242     return CentralMoment(X, n, condition).doit()
#     243 return CentralMoment(X, n, condition).rewrite(Integral)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/symbolic_probability.py:677, in CentralMoment.doit(self, **hints)
#     676 def doit(self, **hints):
# --> 677     return self.rewrite(Expectation).doit(**hints)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/symbolic_probability.py:283, in Expectation.doit(self, **hints)
#     281     return self.func(expr)
#     282 # Otherwise case is simple, pass work off to the ProbabilitySpace
# --> 283 result = pspace(expr).compute_expectation(expr, evaluate=for_rewrite)
#     284 if hasattr(result, 'doit') and for_rewrite:
#     285     return result.doit(**hints)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/crv.py:501, in SingleContinuousPSpace.compute_expectation(self, expr, rvs, evaluate, **kwargs)
#     499 x = self.value.symbol
#     500 try:
# --> 501     return self.distribution.expectation(expr, x, evaluate=evaluate, **kwargs)
#     502 except PoleError:
#     503     return Integral(expr * self.pdf, (x, self.set), **kwargs)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/stats/crv.py:275, in SingleContinuousDistribution.expectation(self, expr, var, evaluate, **kwargs)
#     273         return result
#     274     except PolynomialError:
# --> 275         return integrate(expr * self.pdf(var), (var, self.set), **kwargs)
#     276 else:
#     277     return Integral(expr * self.pdf(var), (var, self.set), **kwargs)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:1567, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1564 integral = Integral(*args, **kwargs)
#    1566 if isinstance(integral, Integral):
# -> 1567     return integral.doit(**doit_flags)
#    1568 else:
#    1569     new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#    1570         for a in integral.args]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:550, in Integral.doit(self, **hints)
#     547         antideriv = function._eval_integral(xab[0],
#     548             **eval_kwargs)
#     549     else:
# --> 550         antideriv = self._eval_integral(
#     551             function, xab[0], **eval_kwargs)
#     552 else:
#     553     # There are a number of tradeoffs in using the
#     554     # Meijer G method. It can sometimes be a lot faster
#    (...)
#     559     # integration methods to try, in what order. See the
#     560     # integrate() docstring for details.
#     561     def try_meijerg(function, xab):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:941, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#     939 # Piecewise antiderivatives need to call special integrate.
#     940 if isinstance(f, Piecewise):
# --> 941     return f.piecewise_integrate(x, **eval_kwargs)
#     943 # let's cut it short if `f` does not depend on `x`; if
#     944 # x is only a dummy, that will be handled below
#     945 if not f.has(x):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/functions/elementary/piecewise.py:295, in Piecewise.piecewise_integrate(self, x, **kwargs)
#     261 """Return the Piecewise with each expression being
#     262 replaced with its antiderivative. To obtain a continuous
#     263 antiderivative, use the :func:`~.integrate` function or method.
#    (...)
#     292 Piecewise._eval_integral
#     293 """
#     294 from sympy.integrals import integrate
# --> 295 return self.func(*[(integrate(e, x, **kwargs), c) for e, c in self.args])
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/functions/elementary/piecewise.py:295, in <listcomp>(.0)
#     261 """Return the Piecewise with each expression being
#     262 replaced with its antiderivative. To obtain a continuous
#     263 antiderivative, use the :func:`~.integrate` function or method.
#    (...)
#     292 Piecewise._eval_integral
#     293 """
#     294 from sympy.integrals import integrate
# --> 295 return self.func(*[(integrate(e, x, **kwargs), c) for e, c in self.args])
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:1567, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1564 integral = Integral(*args, **kwargs)
#    1566 if isinstance(integral, Integral):
# -> 1567     return integral.doit(**doit_flags)
#    1568 else:
#    1569     new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#    1570         for a in integral.args]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:612, in Integral.doit(self, **hints)
#     610     antideriv = None
#     611 else:
# --> 612     antideriv = self._eval_integral(
#     613         function, xab[0], **eval_kwargs)
#     614     if antideriv is None and meijerg is True:
#     615         ret = try_meijerg(function, xab)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/integrals.py:1107, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1105 if h is None and manual is not False:
#    1106     try:
# -> 1107         result = manualintegrate(g, x)
#    1108         if result is not None and not isinstance(result, Integral):
#    1109             if result.has(Integral) and not manual:
#    1110                 # Try to have other algorithms do the integrals
#    1111                 # manualintegrate can't handle,
#    1112                 # unless we were asked to use manual only.
#    1113                 # Keep the rest of eval_kwargs in case another
#    1114                 # method was set to False already
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:2161, in manualintegrate(f, var)
#    2112 def manualintegrate(f, var):
#    2113     """manualintegrate(f, var)
#    2114
#    2115     Explanation
#    (...)
#    2159     sympy.integrals.integrals.Integral
#    2160     """
# -> 2161     result = integral_steps(f, var).eval()
#    2162     # Clear the cache of u-parts
#    2163     _parts_u_cache.clear()
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:2062, in integral_steps(integrand, symbol, **options)
#    2059         return k and issubclass(k, klasses)
#    2060     return _integral_is_subclass
# -> 2062 result = do_one(
#    2063     null_safe(special_function_rule),
#    2064     null_safe(switch(key, {
#    2065         Pow: do_one(null_safe(power_rule), null_safe(inverse_trig_rule),
#    2066                     null_safe(sqrt_linear_rule),
#    2067                     null_safe(quadratic_denom_rule)),
#    2068         Symbol: power_rule,
#    2069         exp: exp_rule,
#    2070         Add: add_rule,
#    2071         Mul: do_one(null_safe(mul_rule), null_safe(trig_product_rule),
#    2072                     null_safe(heaviside_rule), null_safe(quadratic_denom_rule),
#    2073                     null_safe(sqrt_linear_rule),
#    2074                     null_safe(sqrt_quadratic_rule)),
#    2075         Derivative: derivative_rule,
#    2076         TrigonometricFunction: trig_rule,
#    2077         Heaviside: heaviside_rule,
#    2078         DiracDelta: dirac_delta_rule,
#    2079         OrthogonalPolynomial: orthogonal_poly_rule,
#    2080         Number: constant_rule
#    2081     })),
#    2082     do_one(
#    2083         null_safe(trig_rule),
#    2084         null_safe(hyperbolic_rule),
#    2085         null_safe(alternatives(
#    2086             rewrites_rule,
#    2087             substitution_rule,
#    2088             condition(
#    2089                 integral_is_subclass(Mul, Pow),
#    2090                 partial_fractions_rule),
#    2091             condition(
#    2092                 integral_is_subclass(Mul, Pow),
#    2093                 cancel_rule),
#    2094             condition(
#    2095                 integral_is_subclass(Mul, log,
#    2096                 *inverse_trig_functions),
#    2097                 parts_rule),
#    2098             condition(
#    2099                 integral_is_subclass(Mul, Pow),
#    2100                 distribute_expand_rule),
#    2101             trig_powers_products_rule,
#    2102             trig_expand_rule
#    2103         )),
#    2104         null_safe(condition(integral_is_subclass(Mul, Pow), nested_pow_rule)),
#    2105         null_safe(trig_substitution_rule)
#    2106     ),
#    2107     fallback_rule)(integral)
#    2108 del _integral_cache[cachekey]
#    2109 return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:122, in switch.<locals>.switch_rl(expr)
#     120 def switch_rl(expr: _S) -> _S:
#     121     rl = ruledict.get(key(expr), identity)
# --> 122     return rl(expr)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:1508, in sqrt_linear_rule(integral)
#    1505 u = Dummy("u")
#    1506 substituted = integrand.subs({base**(S.One/q): (b/b0)**(S.One/q)*u**(q0/q)
#    1507                               for base, b, q in zip(bases, bs, qs)}).subs(x, (u**q0-a0)/b0)
# -> 1508 substep = integral_steps(substituted*u**(q0-1)*q0/b0, u)
#    1509 if not substep.contains_dont_know():
#    1510     step: Rule = URule(integrand, x, u, u_x, substep)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:2062, in integral_steps(integrand, symbol, **options)
#    2059         return k and issubclass(k, klasses)
#    2060     return _integral_is_subclass
# -> 2062 result = do_one(
#    2063     null_safe(special_function_rule),
#    2064     null_safe(switch(key, {
#    2065         Pow: do_one(null_safe(power_rule), null_safe(inverse_trig_rule),
#    2066                     null_safe(sqrt_linear_rule),
#    2067                     null_safe(quadratic_denom_rule)),
#    2068         Symbol: power_rule,
#    2069         exp: exp_rule,
#    2070         Add: add_rule,
#    2071         Mul: do_one(null_safe(mul_rule), null_safe(trig_product_rule),
#    2072                     null_safe(heaviside_rule), null_safe(quadratic_denom_rule),
#    2073                     null_safe(sqrt_linear_rule),
#    2074                     null_safe(sqrt_quadratic_rule)),
#    2075         Derivative: derivative_rule,
#    2076         TrigonometricFunction: trig_rule,
#    2077         Heaviside: heaviside_rule,
#    2078         DiracDelta: dirac_delta_rule,
#    2079         OrthogonalPolynomial: orthogonal_poly_rule,
#    2080         Number: constant_rule
#    2081     })),
#    2082     do_one(
#    2083         null_safe(trig_rule),
#    2084         null_safe(hyperbolic_rule),
#    2085         null_safe(alternatives(
#    2086             rewrites_rule,
#    2087             substitution_rule,
#    2088             condition(
#    2089                 integral_is_subclass(Mul, Pow),
#    2090                 partial_fractions_rule),
#    2091             condition(
#    2092                 integral_is_subclass(Mul, Pow),
#    2093                 cancel_rule),
#    2094             condition(
#    2095                 integral_is_subclass(Mul, log,
#    2096                 *inverse_trig_functions),
#    2097                 parts_rule),
#    2098             condition(
#    2099                 integral_is_subclass(Mul, Pow),
#    2100                 distribute_expand_rule),
#    2101             trig_powers_products_rule,
#    2102             trig_expand_rule
#    2103         )),
#    2104         null_safe(condition(integral_is_subclass(Mul, Pow), nested_pow_rule)),
#    2105         null_safe(trig_substitution_rule)
#    2106     ),
#    2107     fallback_rule)(integral)
#    2108 del _integral_cache[cachekey]
#    2109 return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:122, in switch.<locals>.switch_rl(expr)
#     120 def switch_rl(expr: _S) -> _S:
#     121     rl = ruledict.get(key(expr), identity)
# --> 122     return rl(expr)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:1204, in mul_rule(integral)
#    1202 coeff, f = integrand.as_independent(symbol)
#    1203 if coeff != 1:
# -> 1204     next_step = integral_steps(f, symbol)
#    1205     if next_step is not None:
#    1206         return ConstantTimesRule(integrand, symbol, coeff, f, next_step)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:2062, in integral_steps(integrand, symbol, **options)
#    2059         return k and issubclass(k, klasses)
#    2060     return _integral_is_subclass
# -> 2062 result = do_one(
#    2063     null_safe(special_function_rule),
#    2064     null_safe(switch(key, {
#    2065         Pow: do_one(null_safe(power_rule), null_safe(inverse_trig_rule),
#    2066                     null_safe(sqrt_linear_rule),
#    2067                     null_safe(quadratic_denom_rule)),
#    2068         Symbol: power_rule,
#    2069         exp: exp_rule,
#    2070         Add: add_rule,
#    2071         Mul: do_one(null_safe(mul_rule), null_safe(trig_product_rule),
#    2072                     null_safe(heaviside_rule), null_safe(quadratic_denom_rule),
#    2073                     null_safe(sqrt_linear_rule),
#    2074                     null_safe(sqrt_quadratic_rule)),
#    2075         Derivative: derivative_rule,
#    2076         TrigonometricFunction: trig_rule,
#    2077         Heaviside: heaviside_rule,
#    2078         DiracDelta: dirac_delta_rule,
#    2079         OrthogonalPolynomial: orthogonal_poly_rule,
#    2080         Number: constant_rule
#    2081     })),
#    2082     do_one(
#    2083         null_safe(trig_rule),
#    2084         null_safe(hyperbolic_rule),
#    2085         null_safe(alternatives(
#    2086             rewrites_rule,
#    2087             substitution_rule,
#    2088             condition(
#    2089                 integral_is_subclass(Mul, Pow),
#    2090                 partial_fractions_rule),
#    2091             condition(
#    2092                 integral_is_subclass(Mul, Pow),
#    2093                 cancel_rule),
#    2094             condition(
#    2095                 integral_is_subclass(Mul, log,
#    2096                 *inverse_trig_functions),
#    2097                 parts_rule),
#    2098             condition(
#    2099                 integral_is_subclass(Mul, Pow),
#    2100                 distribute_expand_rule),
#    2101             trig_powers_products_rule,
#    2102             trig_expand_rule
#    2103         )),
#    2104         null_safe(condition(integral_is_subclass(Mul, Pow), nested_pow_rule)),
#    2105         null_safe(trig_substitution_rule)
#    2106     ),
#    2107     fallback_rule)(integral)
#    2108 del _integral_cache[cachekey]
#    2109 return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:930, in alternatives.<locals>._alternatives(integral)
#     927 count = count + 1
#     928 debug("Rule {}: {}".format(count, rule))
# --> 930 result = rule(integral)
#     931 if (result and not isinstance(result, DontKnowRule) and
#     932     result != integral and result not in alts):
#     933     alts.append(result)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:1885, in substitution_rule(integral)
#    1882 integrand, symbol = integral
#    1884 u_var = Dummy("u")
# -> 1885 substitutions = find_substitutions(integrand, symbol, u_var)
#    1886 count = 0
#    1887 if substitutions:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:875, in find_substitutions(integrand, symbol, u_var)
#     873     continue
#     874 u_diff = manual_diff(u, symbol)
# --> 875 new_integrand = test_subterm(u, u_diff)
#     876 if new_integrand is not False:
#     877     constant, new_integrand = new_integrand
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/integrals/manualintegrate.py:807, in find_substitutions.<locals>.test_subterm(u, u_diff)
#     805 substituted = integrand / u_diff
#     806 debug("substituted: {}, u: {}, u_var: {}".format(substituted, u, u_var))
# --> 807 substituted = manual_subs(substituted, u, u_var).cancel()
#     809 if substituted.has_free(symbol):
#     810     return False
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/core/expr.py:3791, in Expr.cancel(self, *gens, **args)
#    3789 """See the cancel function in sympy.polys"""
#    3790 from sympy.polys.polytools import cancel
# -> 3791 return cancel(self, *gens, **args)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/polytools.py:6890, in cancel(f, _signsimp, *gens, **args)
#    6887                 pass
#    6888         return f.xreplace(dict(reps))
# -> 6890 c, (P, Q) = 1, F.cancel(G)
#    6891 if opt.get('polys', False) and 'gens' not in opt:
#    6892     opt['gens'] = R.symbols
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/rings.py:2193, in PolyElement._gcd(f, g)
#    2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
# -> 2193     return ring.dmp_inner_gcd(f, g)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/compatibility.py:663, in IPolys.dmp_inner_gcd(self, f, g)
#     662 def dmp_inner_gcd(self, f, g):
# --> 663     H, F, G = dmp_inner_gcd(self.to_dense(f), self.to_dense(g), self.ngens-1, self.domain)
#     664     return (self.from_dense(H), self.from_dense(F), self.from_dense(G))
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/euclidtools.py:1557, in _dmp_inner_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
# -> 1557 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/euclidtools.py:1068, in dmp_rr_prs_gcd(f, g, u, K)
#    1065 fc, F = dmp_primitive(f, u, K)
#    1066 gc, G = dmp_primitive(g, u, K)
# -> 1068 h = dmp_subresultants(F, G, u, K)[-1]
#    1069 c, _, _ = dmp_rr_prs_gcd(fc, gc, u - 1, K)
#    1071 if K.is_negative(dmp_ground_LC(h, u, K)):
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:1238, in dmp_prem(f, g, u, K)
#    1235 j, N = dr - dg, N - 1
#    1237 R = dmp_mul_term(r, lc_g, 0, u, K)
# -> 1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#    1241 _dr, dr = dr, dmp_degree(r, u)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:184, in <listcomp>(.0)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (1 times)]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in dmp_add(f, g, u, K)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in <listcomp>(.0)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in dmp_add(f, g, u, K)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in <listcomp>(.0)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
#     [... skipping similar frames: dmp_add at line 578 (6 times), <listcomp> at line 578 (5 times)]
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in <listcomp>(.0)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densearith.py:578, in dmp_add(f, g, u, K)
#     575 v = u - 1
#     577 if df == dg:
# --> 578     return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     579 else:
#     580     k = abs(df - dg)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densebasic.py:301, in dmp_strip(f, u)
#     298 i, v = 0, u - 1
#     300 for c in f:
# --> 301     if not dmp_zero_p(c, v):
#     302         break
#     303     else:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/polys/densebasic.py:695, in dmp_zero_p(f, u)
#     690             f, v = f[d - n], v - 1
#     692     return f
# --> 695 def dmp_zero_p(f, u):
#     696     """
#     697     Return ``True`` if ``f`` is zero in ``K[X]``.
#     698
#    (...)
#     708
#     709     """
#     710     while u:
#
# KeyboardInterrupt:

# %%
solveset(delta, sig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 solveset(delta,sig)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solveset.py:2252, in solveset(f, symbol, domain)
#    2250 if symbol not in _rc:
#    2251     x = _rc[0] if domain.is_subset(S.Reals) else _rc[1]
# -> 2252     rv = solveset(f.xreplace({symbol: x}), x, domain)
#    2253     # try to use the original symbol if possible
#    2254     try:
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solveset.py:2276, in solveset(f, symbol, domain)
#    2273     f = f.xreplace({d: e})
#    2274 f = piecewise_fold(f)
# -> 2276 return _solveset(f, symbol, domain, _check=True)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solveset.py:1139, in _solveset(f, symbol, domain, _check)
#    1137                     result += t_result
#    1138         else:
# -> 1139             result += solver(equation, symbol)
#    1141 elif rhs_s is not S.EmptySet:
#    1142     result = ConditionSet(symbol, Eq(f, 0), domain)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solveset.py:1040, in _solveset.<locals>.<lambda>(f, x, domain)
#    1037         f = a/m + h  # XXX condition `m != 0` should be added to soln
#    1039 # assign the solvers to use
# -> 1040 solver = lambda f, x, domain=domain: _solveset(f, x, domain)
#    1041 inverter = lambda f, rhs, symbol: _invert(f, rhs, symbol, domain)
#    1043 result = S.EmptySet
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solveset.py:1104, in _solveset(f, symbol, domain, _check)
#    1102 for equation in [lhs - rhs for rhs in rhs_s]:
#    1103     if equation == f:
# -> 1104         u = unrad(f, symbol)
#    1105         if u:
#    1106             result += _solve_radical(equation, u,
#    1107                                      symbol,
#    1108                                      solver)
#
# File ~/vienv-ds/lib/python3.11/site-packages/sympy/solvers/solvers.py:3413, in unrad(eq, *syms, **flags)
#    3411 syms = set(syms) or eq.free_symbols  # _take uses this
#    3412 poly = eq.as_poly()
# -> 3413 gens = [g for g in poly.gens if _take(g)]
#    3414 if not gens:
#    3415     return
#
# AttributeError: 'NoneType' object has no attribute 'gens'

# %%
mu_range = np.linspace(0, 100)
sig_range = np.linspace(0.01, 10)
mumu, sigsig = np.meshgrid(mu_range, sig_range)
delta_n(mumu, sigsig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 4
#       2 sig_range = np.linspace(0.01, 10)
#       3 mumu, sigsig = np.meshgrid(mu_range, sig_range)
# ----> 4 delta_n(mumu, sigsig)
#
# File <lambdifygenerated-2>:5, in _lambdifygenerated(Dummy_9724, Dummy_9723)
#       1 def _lambdifygenerated(Dummy_9724, Dummy_9723):
#       2     return (  # Not supported in Python with numpy:
#       3   # Variance
#       4   # Variance
# ----> 5 (1/2)*(Dummy_9724**2*Variance(Z)**(-1.0) - (Dummy_9723**2 + Dummy_9724**2)**2*Variance(Z**2)**(-1.0)))
#
# NameError: name 'Variance' is not defined
